# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/loan.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# ## Histrogram

# %%
df["ApplicantIncome"].hist(bins=100)
# Out:
# <Axes: >

# %%
plt.hist(df["ApplicantIncome"], bins=100)
plt.show()

# %%
df["Loan_Amount_Term"].unique().tolist()
# Out:
# [360.0, 120.0, 240.0, nan, 180.0, 60.0, 300.0, 480.0, 36.0, 84.0, 12.0]

# %%
plt.hist(df["Loan_Amount_Term"], bins=10)
plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(df["ApplicantIncome"], df["CoapplicantIncome"])
plt.xlabel("Applicant Income")
plt.ylabel("Coapplicant Income")
plt.show()

# %%
df_titanic = pd.read_csv("../data/titanic.csv")
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
plt.scatter(df_titanic["Age"], df_titanic["Fare"])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
plt.scatter(df_titanic["Age"], df_titanic["Pclass"])
plt.xlabel("Age")
plt.ylabel("Passenger Class")
plt.show()

# %%
# Solution 1
df_titanic_male = df_titanic[df_titanic["Sex"] == 'male']
df_titanic_female = df_titanic[df_titanic["Sex"] == 'female']

plt.scatter(df_titanic_male["Age"], df_titanic_male["Survived"], c='blue', alpha=0.5)
plt.scatter(df_titanic_female["Age"], df_titanic_female["Survived"], c='red', alpha=0.5)
plt.yticks([0, 1], ['Not Survived', 'Survived'])
plt.xticks(rotation=45)
plt.legend(['Male', 'Female'])
plt.xlabel('Age')
plt.ylabel('Survived')
plt.show()

# %%
# Solution 2
df_titanic["Sex_color"] = np.where(df_titanic["Sex"] == 'male', '#0000ff', '#ff0000')

plt.scatter(df_titanic["Age"], df_titanic["Survived"], c=df_titanic["Sex_color"], alpha=0.5)
plt.yticks([0, 1], ['Not Survived', 'Survived'])
plt.xticks(rotation=45)
plt.xlabel('Age')
plt.ylabel('Survived')
plt.show()

# %% [markdown]
# ## Box Plot

# %%
plt.boxplot(df_titanic[["Age", "Fare"]].dropna())
plt.xticks([1, 2], ['Age', 'Fare'])
plt.show()

# %%
plt.boxplot([df_titanic[df_titanic["Sex"] == 'male']["Age"].dropna(),
             df_titanic[df_titanic["Sex"] == 'female']["Age"].dropna()])
plt.xticks([1, 2],['Male', 'Female'])
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ## Violin Plot

# %%
plt.violinplot([df_titanic[df_titanic["Sex"] == 'male']["Age"].dropna(),
                df_titanic[df_titanic["Sex"] == 'female']["Age"].dropna()],
               showmedians=True,
               # showmeans=True,
               vert=True)
plt.xticks([1, 2],['Male', 'Female'])
plt.ylabel('Age')
plt.show()
