# %% [markdown]
# # SQL Murder Mystery

# %%
import sqlite3
import pandas as pd

pd.set_option('display.max_colwidth', None)

# %%
db_path = "../data/sql-murder-mystery.db"

conn = sqlite3.connect(db_path)

# %%
df_person = pd.read_sql_query("SELECT * FROM person", conn)
df_dl = pd.read_sql_query("SELECT * FROM drivers_license", conn)
df_interview = pd.read_sql_query("SELECT * FROM interview", conn)
df_report = pd.read_sql_query("SELECT * FROM crime_scene_report", conn)
df_gym = pd.read_sql_query("SELECT * FROM get_fit_now_member", conn)
df_checkin = pd.read_sql_query("SELECT * FROM get_fit_now_check_in", conn)
df_fb = pd.read_sql_query("SELECT * FROM facebook_event_checkin", conn)
conn.close()

# %% [markdown]
# ## Checking data frames

# %%
df_person.head()
# Out:
#       id                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn
# 0  747714076
# 1  477972044
# 2  828638512
# 3  614621061
# 4  223877684

# %%
df_dl.head()
# Out:
#        id  age  height eye_color hair_color  gender plate_number  car_make  \
# 0  100280   72      57     brown        red    male       P24L4U     Acura
# 1  100460   63      72     brown      brown  female       XF02T6  Cadillac
# 2  101029   62      74     green      green  female       VKY5KR     Scion
# 3  101198   43      54     amber      brown  female       Y5NZ08    Nissan
# 4  101255   18      79      blue       grey  female       5162Z1     Lexus
#
#   car_model
# 0       MDX
# 1       SRX
# 2        xB
# 3     Rogue
# 4        GS

# %%
df_interview.head()
# Out:
#    person_id  \
# 0      28508
# 1      63713
# 2      86208
# 3      35267
# 4      33856
#
#                                                                 transcript
# 0                                      ‘I deny it!’ said the March Hare.\n
# 1                                                                       \n
# 2                            way, and the whole party swam to the shore.\n
# 3  lessons in here? Why, there’s hardly room for YOU, and no room at all\n
# 4                                                                       \n

# %%
df_report.head()
# Out:
#        date     type                                              description  \
# 0  20180115  robbery        A Man Dressed as Spider-Man Is on a Robbery Spree
# 1  20180115   murder                        Life? Dont talk to me about life.
# 2  20180115   murder      Mama, I killed a man, put a gun against his head...
# 3  20180215   murder                               REDACTED REDACTED REDACTED
# 4  20180215   murder  Someone killed the guard! He took an arrow to the knee!
#
#        city
# 0       NYC
# 1    Albany
# 2      Reno
# 3  SQL City
# 4  SQL City

# %%
df_gym.head()
# Out:
#       id  person_id                name  membership_start_date  \
# 0  NL318      65076     Everette Koepke               20170926
# 1  AOE21      39426        Noe Locascio               20171005
# 2  2PN28      63823  Jeromy Heitschmidt               20180215
# 3  0YJ24      80651      Waneta Wellard               20171206
# 4  3A08L      32858        Mei Bianchin               20170401
#
#   membership_status
# 0              gold
# 1           regular
# 2            silver
# 3              gold
# 4            silver

# %%
df_checkin.head()
# Out:
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
df_fb.head()
# Out:
#    person_id  event_id  \
# 0      28508      5880
# 1      63713      3865
# 2      63713      3999
# 3      63713      6436
# 4      82998      4470
#
#                                                             event_name  \
# 0                      Nudists are people who wear one-button suits.\n
# 1  but that's because it's the best book on anything for the layman.\n
# 2                             If Murphy's Law can go wrong, it will.\n
# 3     Old programmers never die.  They just branch to a new address.\n
# 4                                 Help a swallow land at Capistrano.\n
#
#        date
# 0  20170913
# 1  20171009
# 2  20170502
# 3  20170926
# 4  20171022

# %% [markdown]
# ## Crime Scene Report

# %%
# SELECT description FROM report
# WHERE date = 20180118

# AND: &
# OR: |

df_report[(df_report["date"] == 20180115)
          & (df_report["city"] == 'SQL City')
          & (df_report["type"] == 'murder')]
# Out:
#           date    type  \
# 1227  20180115  murder
#
#                                                                                                                                                                                     description  \
# 1227  Security footage shows that there were 2 witnesses. The first witness lives at the last house on "Northwestern Dr". The second witness, named Annabel, lives somewhere on "Franklin Ave".
#
#           city
# 1227  SQL City

# %% [markdown]
# ## Finding the witnesses

# %%
# The first witness lives at the last house on "Northwestern Dr".

max_address_number = df_person[df_person["address_street_name"] == 'Northwestern Dr']["address_number"].max()

df_person[(df_person["address_street_name"] == 'Northwestern Dr')
         & (df_person["address_number"] == max_address_number)]
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
#
#            ssn
# 499  111564949

# %%
# The second witness, named Annabel, lives somewhere on "Franklin Ave".

df_person[(df_person["address_street_name"] == 'Franklin Ave')
         & (df_person["name"].str.contains('Annabel'))]
# Out:
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
# Finding both witnesses in one command

df_witness = df_person[((df_person["address_street_name"] == 'Northwestern Dr')
         & (df_person["address_number"] == max_address_number))
         |
         ((df_person["address_street_name"] == 'Franklin Ave')
         & (df_person["name"].str.contains('Annabel')))]

df_witness
# Out:
#         id            name  license_id  address_number address_street_name  \
# 499  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 499  111564949
# 665  318771143

# %% [markdown]
# ## Merging with Interview

# %%
# SELECT * FROM witness
# JOIN interview ON witness.id = interview.person_id

df = df_witness.merge(df_interview, how="inner", left_on="id", right_on="person_id")

# alternatively:
# df = df_interview.merge(df_witness, how="inner", left_on="person_id", right_on="id")

df
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  14887  Morty Schapiro      118009            4919     Northwestern Dr
# 1  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn  person_id  \
# 0  111564949      14887
# 1  318771143      16371
#
#                                                                                                                                                                                                                         transcript
# 0  I heard a gunshot and then saw a man run out. He had a "Get Fit Now Gym" bag. The membership number on the bag started with "48Z". Only gold members have those bags. The man got into a car with a plate that included "H42W".
# 1                                                                                                            I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %% [markdown]
# ## Finding Murderer

# %%
# He had a "Get Fit Now Gym" bag.
# The membership number on the bag started with "48Z".
# Only gold members have those bags.
# The man got into a car with a plate that included "H42W".
# I saw the murder happen, and I recognized the killer from my gym when I was working out last week on January the 9th.

# %%
df_gym = df_gym.merge(df_checkin, how="inner", left_on="id", right_on="membership_id")
df_gym.head()
# Out:
#       id  person_id             name  membership_start_date membership_status  \
# 0  NL318      65076  Everette Koepke               20170926              gold
# 1  NL318      65076  Everette Koepke               20170926              gold
# 2  NL318      65076  Everette Koepke               20170926              gold
# 3  NL318      65076  Everette Koepke               20170926              gold
# 4  NL318      65076  Everette Koepke               20170926              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time
# 0         NL318       20180212            329             365
# 1         NL318       20170811            469             920
# 2         NL318       20180429            506             554
# 3         NL318       20180128            124             759
# 4         NL318       20171027            418            1019

# %%
df_gym_filtered = df_gym[df_gym["id"].str.startswith("48Z")
      & (df_gym["membership_status"] == 'gold')
      & (df_gym["check_in_date"] == 20180109)]

df = df_gym_filtered.merge(df_person, how="inner", left_on="person_id", right_on="id")
df.head()
# Out:
#     id_x  person_id         name_x  membership_start_date membership_status  \
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time   id_y  \
# 0         48Z7A       20180109           1600            1730  28819
# 1         48Z55       20180109           1530            1700  67318
#
#           name_y  license_id  address_number    address_street_name        ssn
# 0   Joe Germuska      173289             111                Fisk Rd  138909730
# 1  Jeremy Bowers      423327             530  Washington Pl, Apt 3A  871539279

# %%
df = df.merge(df_dl, how="inner", left_on="license_id", right_on="id")
df.head()
# Out:
#     id_x  person_id         name_x  membership_start_date membership_status  \
# 0  48Z55      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time   id_y  ...  \
# 0         48Z55       20180109           1530            1700  67318  ...
#
#          ssn      id  age height eye_color  hair_color  gender  plate_number  \
# 0  871539279  423327   30     70     brown       brown    male        0H42W2
#
#     car_make car_model
# 0  Chevrolet  Spark LS
#
# [1 rows x 24 columns]

# %%
df[df["plate_number"].str.contains("H42W")]
# Out:
#     id_x  person_id         name_x  membership_start_date membership_status  \
# 0  48Z55      67318  Jeremy Bowers               20160101              gold
#
#   membership_id  check_in_date  check_in_time  check_out_time   id_y  ...  \
# 0         48Z55       20180109           1530            1700  67318  ...
#
#          ssn      id  age height eye_color  hair_color  gender  plate_number  \
# 0  871539279  423327   30     70     brown       brown    male        0H42W2
#
#     car_make car_model
# 0  Chevrolet  Spark LS
#
# [1 rows x 24 columns]

# %% [markdown]
# ## Finding Person Behind Murder

# %%
df_interview[df_interview["person_id"] == 67318]
# Out:
#       person_id  \
# 4990      67318
#
#                                                                                                                                                                                                                                               transcript
# 4990  I was hired by a woman with a lot of money. I don't know her name but I know she's around 5'5" (65") or 5'7" (67"). She has red hair and she drives a Tesla Model S. I know that she attended the SQL Symphony Concert 3 times in December 2017.\n

# %%
# I was hired by a woman with a lot of money.
# I don't know her name but I know she's around 5'5" (65") or 5'7" (67").
# She has red hair and she drives a Tesla Model S.
# I know that she attended the SQL Symphony Concert 3 times in December 2017.

df = df_person.merge(df_dl, how="inner", left_on="license_id", right_on="id")
df.head()
# Out:
#     id_x                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 2  10010            Muoi Cary      385336             741     Northwestern Dr
# 3  10016          Era Moselle      431897            1987       Wood Glade St
# 4  10025         Trena Hornby      550890             276       Daws Hill Way
#
#          ssn    id_y  age  height eye_color hair_color  gender plate_number  \
# 0  747714076  993845   46      59     black      green    male       557472
# 1  477972044  861794   54      74     black      white  female       3P6DMS
# 2  828638512  385336   24      79      blue      green  female       GM6Y5J
# 3  614621061  431897   22      75     amber        red  female       461S1M
# 4  223877684  550890   45      60      blue      black  female       8030O8
#
#         car_make       car_model
# 0       Chrysler  Town & Country
# 1            BMW      M Roadster
# 2  Mercedes-Benz       CLS-Class
# 3           Ford          Ranger
# 4         Toyota     Tacoma Xtra

# %%
df = df.merge(df_fb, left_on="id_x", right_on="person_id")
df.head()
# Out:
#     id_x                 name  license_id  address_number address_street_name  \
# 0  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 1  10000   Christoper Peteuil      993845             624        Bankhall Ave
# 2  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 3  10007  Kourtney Calderwood      861794            2791       Gustavus Blvd
# 4  10010            Muoi Cary      385336             741     Northwestern Dr
#
#          ssn    id_y  age  height eye_color hair_color  gender plate_number  \
# 0  747714076  993845   46      59     black      green    male       557472
# 1  747714076  993845   46      59     black      green    male       557472
# 2  477972044  861794   54      74     black      white  female       3P6DMS
# 3  477972044  861794   54      74     black      white  female       3P6DMS
# 4  828638512  385336   24      79      blue      green  female       GM6Y5J
#
#         car_make       car_model  person_id  event_id  \
# 0       Chrysler  Town & Country      10000       241
# 1       Chrysler  Town & Country      10000      1137
# 2            BMW      M Roadster      10007      6447
# 3            BMW      M Roadster      10007      4273
# 4  Mercedes-Benz       CLS-Class      10010      3581
#
#                                                                event_name  \
# 0                         Steinbach's Guideline for Systems Programming\n
# 1                             The Universe is laughing behind your back\n
# 2  Green light in A.M. for new projects.  Red light in P.M. for traffic\n
# 3         Modern man is the missing link between apes and human beings.\n
# 4                upon to act in accordance with the dictates of reason.\n
#
#        date
# 0  20170306
# 1  20171130
# 2  20170925
# 3  20171017
# 4  20180319

# %%
df_copy = df[(df["gender"] == 'female')
  & (df["hair_color"] == 'red')
  & (df["height"].between(65, 67))
  & (df["car_make"] == 'Tesla')
  & (df["car_model"] == 'Model S')]
df_copy
# Out:
#         id_x              name  license_id  address_number  \
# 19955  99716  Miranda Priestly      202298            1883
# 19956  99716  Miranda Priestly      202298            1883
# 19957  99716  Miranda Priestly      202298            1883
#
#       address_street_name        ssn    id_y  age  height eye_color  \
# 19955          Golden Ave  987756388  202298   68      66     green
# 19956          Golden Ave  987756388  202298   68      66     green
# 19957          Golden Ave  987756388  202298   68      66     green
#
#       hair_color  gender plate_number car_make car_model  person_id  event_id  \
# 19955        red  female       500123    Tesla   Model S      99716      1143
# 19956        red  female       500123    Tesla   Model S      99716      1143
# 19957        red  female       500123    Tesla   Model S      99716      1143
#
#                  event_name      date
# 19955  SQL Symphony Concert  20171206
# 19956  SQL Symphony Concert  20171212
# 19957  SQL Symphony Concert  20171229

# %%
df_copy.groupby(["event_name"])[["event_name"]].count()
# Out:
#                       event_name
# event_name
# SQL Symphony Concert           3

# %%
type(df["event_name"].unique())
# Out:
# numpy.ndarray

# %%
type(df["event_name"].unique().tolist())
# Out:
# list
